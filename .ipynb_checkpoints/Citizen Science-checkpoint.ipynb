# %% [markdown]
# # Imports

# %%
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Load in Citizen Science Data

# %%
data_path = os.path.join(os.getcwd(), '', 'citizenscience.csv')
citsci = pd.read_csv(data_path, delimiter = ',',  header=None, names=['user_id', 'timestamp'])

# %%
citsci['timestamp'] = pd.to_datetime(citsci['timestamp'])

# %%
citsci.describe()
# Out:
#                          user_id            timestamp
# count                      99999                99999
# unique                       943                13370
# top     5050a6760454e27aae0026db  2014-12-29 21:38:00
# freq                        5531                   69
# first                        NaN  2014-12-23 16:53:00
# last                         NaN  2015-01-05 17:33:00

# %%
citsci.dtypes
# Out:
# user_id              object
# timestamp    datetime64[ns]
# dtype: object

# %%
citsci.head()
# Out:
#                     user_id           timestamp
# 0  54999c8d9cd118282b001784 2014-12-23 16:53:00
# 1  54999c91bb7b56040d0011e8 2014-12-23 16:53:00
# 2  54999c8fbb7b565d7e000a7c 2014-12-23 16:53:00
# 3  54999cb29cd1184d77000539 2014-12-23 16:53:00
# 4  54068fab91ad6b597e000f97 2014-12-23 16:53:00

# %%
citsci = citsci.sort_values(['user_id', 'timestamp'])

# %% [markdown]
# # Group Records by User_Id

# %%
grouped_users = citsci.groupby('user_id')['timestamp'].agg(['first','last'])

# %%
grouped_users.head()
# Out:
#                                        first                last
# user_id
# 4d5835cc2a82e278e6000028 2015-01-05 09:07:00 2015-01-05 15:52:00
# 4fcaa6daae60e44a1900000b 2015-01-01 03:36:00 2015-01-01 03:38:00
# 50085cfc44dff81137000020 2014-12-28 22:32:00 2015-01-01 20:55:00
# 5013adf30454e27ae4000002 2015-01-02 22:12:00 2015-01-02 22:12:00
# 503e2b5eba40af242e000052 2014-12-26 13:12:00 2014-12-29 17:24:00

# %%
grouped_users['length'] = grouped_users['last'] - grouped_users['first']

# %%
longest_user_id = grouped_users.sort_values('length', ascending=False).iloc[0]
longest_user_id = '508920379177d041ea003fd8'
longest_user = citsci[citsci['user_id'] == '508920379177d041ea003fd8']
longest_user
# Out:
#                         user_id           timestamp
# 12     508920379177d041ea003fd8 2014-12-23 16:53:00
# 16     508920379177d041ea003fd8 2014-12-23 16:53:00
# 21     508920379177d041ea003fd8 2014-12-23 16:53:00
# 44     508920379177d041ea003fd8 2014-12-23 16:54:00
# 612    508920379177d041ea003fd8 2014-12-23 17:10:00
# 698    508920379177d041ea003fd8 2014-12-23 17:25:00
# 7210   508920379177d041ea003fd8 2014-12-24 16:01:00
# 7211   508920379177d041ea003fd8 2014-12-24 16:01:00
# 7212   508920379177d041ea003fd8 2014-12-24 16:02:00
# 7213   508920379177d041ea003fd8 2014-12-24 16:02:00
# 7214   508920379177d041ea003fd8 2014-12-24 16:02:00
# 18141  508920379177d041ea003fd8 2014-12-26 15:52:00
# 18142  508920379177d041ea003fd8 2014-12-26 15:52:00
# 18144  508920379177d041ea003fd8 2014-12-26 15:53:00
# 18146  508920379177d041ea003fd8 2014-12-26 15:54:00
# 18149  508920379177d041ea003fd8 2014-12-26 15:54:00
# 18152  508920379177d041ea003fd8 2014-12-26 15:54:00
# 18153  508920379177d041ea003fd8 2014-12-26 15:54:00
# 2014-12-26 15:52:00    2
# 2014-12-26 15:53:00    1
# 2014-12-26 15:54:00    4
# 2014-12-26 15:55:00    3
# 2014-12-26 15:57:00    1
# 2014-12-27 15:36:00    1
# 2014-12-27 15:37:00    2
# 2014-12-27 15:38:00    1
# 2014-12-27 15:55:00    3
# 2014-12-27 15:56:00    5
# 2014-12-27 15:57:00    1
# 2014-12-27 15:58:00    1
# 2014-12-27 16:01:00    2
# 2014-12-27 16:11:00    2
# 2014-12-27 16:12:00    1
# 2014-12-27 16:13:00    1
# 2014-12-27 16:14:00    4
# 2014-12-27 16:15:00    5
# 2014-12-27 16:24:00    4
# 2014-12-27 16:25:00    1
# 2014-12-27 16:34:00    3
# 2014-12-27 16:36:00    1
# 2014-12-29 15:22:00    5
# 2014-12-29 15:24:00    2
#                       ..
# 2015-01-05 15:48:00    1
# 2015-01-05 16:00:00    1
# 2015-01-05 16:01:00    4
# 2015-01-05 16:04:00    1
# 2015-01-05 16:05:00    5
# 2015-01-05 16:06:00    3
# 2015-01-05 16:07:00    3
# 2015-01-05 16:09:00    1
# 2015-01-05 16:10:00    1
# 2015-01-05 16:11:00    1
# 2015-01-05 16:20:00    1
# 2015-01-05 16:21:00    1
# 2015-01-05 16:25:00    4
# 2015-01-05 16:26:00    1
# 2015-01-05 16:40:00    1
# 2015-01-05 16:41:00    4
# 2015-01-05 16:42:00    1
# 2015-01-05 17:00:00    1
# 2015-01-05 17:01:00    2
# 2015-01-05 17:02:00    4
# 2015-01-05 17:03:00    4
# 2015-01-05 17:04:00    5
# 2015-01-05 17:05:00    2
# 2015-01-05 17:06:00    1
# 2015-01-05 17:14:00    4
# 2015-01-05 17:15:00    4
# 2015-01-05 17:16:00    1
# 2015-01-05 17:30:00    3
# 2015-01-05 17:31:00    2
# 2015-01-05 17:32:00    1
# Length: 257, dtype: int64

# %% [markdown]
# # Group into Session Data

# %%
sorted_citsci = citsci.sort_values(['user_id', 'timestamp'])

# %%
gt_30min = sorted_citsci.timestamp.diff() > pd.datetools.timedelta(minutes=30)
# Out:
# /Users/thomascartwright/miniconda3/envs/ipp/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.core.datetools.timedelta is deprecated. Please use datetime.timedelta instead.
#   """Entry point for launching an IPython kernel.

# %%
diff_user = sorted_citsci.user_id != sorted_citsci.user_id.shift()

# %%
session_id = (diff_user | gt_30min).cumsum()

# %%
from string import ascii_uppercase

# %%
citsci['session_id'] = session_id

# %%
citsci
# Out:
#                         user_id           timestamp  session_id
# 95970  4d5835cc2a82e278e6000028 2015-01-05 09:07:00           1
# 95971  4d5835cc2a82e278e6000028 2015-01-05 09:07:00           1
# 95972  4d5835cc2a82e278e6000028 2015-01-05 09:08:00           1
# 96058  4d5835cc2a82e278e6000028 2015-01-05 09:33:00           1
# 98712  4d5835cc2a82e278e6000028 2015-01-05 15:04:00           2
# 98728  4d5835cc2a82e278e6000028 2015-01-05 15:04:00           2
# 98735  4d5835cc2a82e278e6000028 2015-01-05 15:05:00           2
# 98745  4d5835cc2a82e278e6000028 2015-01-05 15:06:00           2
# 99338  508920379177d041ea003fd8 2015-01-05 17:03:00         321
# 99339  508920379177d041ea003fd8 2015-01-05 17:03:00         321
# 99340  508920379177d041ea003fd8 2015-01-05 17:03:00         321
# 99341  508920379177d041ea003fd8 2015-01-05 17:04:00         321
# 99342  508920379177d041ea003fd8 2015-01-05 17:04:00         321
# 99343  508920379177d041ea003fd8 2015-01-05 17:04:00         321
# 99347  508920379177d041ea003fd8 2015-01-05 17:04:00         321
# 99350  508920379177d041ea003fd8 2015-01-05 17:04:00         321
# 99354  508920379177d041ea003fd8 2015-01-05 17:05:00         321
# 99356  508920379177d041ea003fd8 2015-01-05 17:05:00         321
# 99357  508920379177d041ea003fd8 2015-01-05 17:06:00         321
# 99439  508920379177d041ea003fd8 2015-01-05 17:14:00         321
# 99440  508920379177d041ea003fd8 2015-01-05 17:14:00         321
# 99442  508920379177d041ea003fd8 2015-01-05 17:14:00         321
# 99443  508920379177d041ea003fd8 2015-01-05 17:14:00         321
# 99448  508920379177d041ea003fd8 2015-01-05 17:15:00         321
# 99449  508920379177d041ea003fd8 2015-01-05 17:15:00         321
# 99451  508920379177d041ea003fd8 2015-01-05 17:15:00         321
# 99455  508920379177d041ea003fd8 2015-01-05 17:15:00         321
# 99486  508920379177d041ea003fd8 2015-01-05 17:16:00         321
# 99901  508920379177d041ea003fd8 2015-01-05 17:30:00         321
# 99905  508920379177d041ea003fd8 2015-01-05 17:30:00         321
# 99908  508920379177d041ea003fd8 2015-01-05 17:30:00         321
# 99934  508920379177d041ea003fd8 2015-01-05 17:31:00         321
# 99942  508920379177d041ea003fd8 2015-01-05 17:31:00         321
# 99958  508920379177d041ea003fd8 2015-01-05 17:32:00         321
#
# [543 rows x 3 columns]

# %% [markdown]
# # Add new columns to each HIT

# %% [markdown]
# ### Add field for session duration so far

# %%
session_duration = citsci['timestamp'] - citsci.groupby('session_id')['timestamp'].transform('first')
citsci['session_duration'] = session_duration.dt.seconds // 60

# %% [markdown]
# ### Add field for time since last HIT

# %%
idle_time = citsci.groupby('session_id')['timestamp'].diff().fillna(0)
citsci['idle_time'] = idle_time.dt.seconds // 60

# %% [markdown]
# ### Add field for number of HITs in this session

# %%
total_hits = citsci.groupby(["session_id"]).cumcount()
citsci['total_hits'] = total_hits

# %% [markdown]
# ### Add field for whether churn will occur in 5 minutes

# %%
import datetime
will_churn = citsci.groupby('session_id')['timestamp'].transform('last') - citsci['timestamp']
will_churn = will_churn < datetime.timedelta(minutes=5)
citsci['will_churn'] = will_churn

# %% [markdown]
# # Normalise the Data

# %%
citsci["session_duration"]=((citsci["session_duration"]-citsci["session_duration"].min())/(citsci["session_duration"].max()-citsci["session_duration"].min()))
citsci["idle_time"]=((citsci["idle_time"]-citsci["idle_time"].min())/(citsci["idle_time"].max()-citsci["idle_time"].min()))
citsci["total_hits"]=((citsci["total_hits"]-citsci["total_hits"].min())/(citsci["total_hits"].max()-citsci["total_hits"].min()))

# %% [markdown]
# # Inspect Balance of Classes

# %%
citsci['will_churn'].sum()
# Out:
# 29904

# %% [markdown]
# # Split Data into Train/Test

# %%
citsci.head()
# Out:
#                         user_id           timestamp  session_id  \
# 95970  4d5835cc2a82e278e6000028 2015-01-05 09:07:00           1
# 95971  4d5835cc2a82e278e6000028 2015-01-05 09:07:00           1
# 95972  4d5835cc2a82e278e6000028 2015-01-05 09:08:00           1
# 96058  4d5835cc2a82e278e6000028 2015-01-05 09:33:00           1
# 98712  4d5835cc2a82e278e6000028 2015-01-05 15:04:00           2
#
#        session_duration  idle_time  total_hits  will_churn
# 95970          0.000000   0.000000    0.000000       False
# 95971          0.000000   0.000000    0.001307       False
# 95972          0.004651   0.033333    0.002614       False
# 96058          0.120930   0.833333    0.003922        True
# 98712          0.000000   0.000000    0.000000       False

# %%
from sklearn.model_selection import train_test_split
X = citsci[['session_duration', 'idle_time', 'total_hits']]
y = citsci['will_churn']
# Out:
# /Users/thomascartwright/miniconda3/envs/ipp/lib/python3.7/site-packages/sklearn/utils/__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.75, test_size=0.25, random_state=0)

# %% [markdown]
# # Train Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0, solver='lbfgs', class_weight='balanced').fit(X_train, y_train)

# %%
clf.score(X_test, y_test)
# Out:
# 0.49752

# %%
np.sum(clf.predict(X_train))
# Out:
# 49499

# %%
lr_pred = clf.predict(X_test)

# %% [markdown]
# # Train a Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, criterion='entropy', class_weight='balanced')
rf.fit(X_train, y_train)
prediction_test = rf.score(X_test, y_test)
# Out:
# /Users/thomascartwright/miniconda3/envs/ipp/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
prediction_test
# Out:
# 0.59716

# %%
rf_pred = rf.predict(X_test)

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(cm, classes=None, title='Confusion matrix'):
    """Plots a confusion matrix."""
    if classes is not None:
        sns.heatmap(cm, xticklabels=classes, yticklabels=classes, vmin=0., vmax=1., annot=True)
    else:
        sns.heatmap(cm, vmin=0., vmax=1.)
    plt.title(title)
    plt.ylabel('True label')

# %% [markdown]
# ### Logistic Regression

# %%
cm = confusion_matrix(y_test, lr_pred)
cm_norm = cm/cm.sum(axis=1)[:, np.newaxis]

# Plot the confusion matrix as a heatmap
plt.figure()
plot_confusion_matrix(cm_norm, classes=['0', '1'])
plt.title("Classification of News Documents")
plt.show()

# %% [markdown]
# ### Random Forest

# %%
cm = confusion_matrix(y_test, rf_pred)
cm_norm = cm/cm.sum(axis=1)[:, np.newaxis]

# Plot the confusion matrix as a heatmap
plt.figure()
plot_confusion_matrix(cm_norm, classes=['0', '1'])
plt.title("Classification of News Documents")
plt.show()

# %% [markdown]
# # Neural Network

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(1, ), 
                    activation='relu',
                    solver='sgd')
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='sgd', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
nn_pred = mlp.predict_proba(X_test)
nn_pred
# Out:
# array([[0.70019284, 0.29980716],
#        [0.70019284, 0.29980716],
#        [0.70019284, 0.29980716],
#        ...,
#        [0.70019284, 0.29980716],
#        [0.70019284, 0.29980716],
#        [0.70019284, 0.29980716]])

# %%
cm = confusion_matrix(y_test, nn_pred)
cm_norm = cm/cm.sum(axis=1)[:, np.newaxis]

# Plot the confusion matrix as a heatmap
plt.figure()
plot_confusion_matrix(cm_norm, classes=['0', '1'])
plt.title("Classification of News Documents")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-18715c645cad> in <module>()
# ----> 1 cm = confusion_matrix(y_test, nn_pred)
#       2 cm_norm = cm/cm.sum(axis=1)[:, np.newaxis]
#       3
#       4 # Plot the confusion matrix as a heatmap
#       5 plt.figure()
#
# ~/miniconda3/envs/ipp/lib/python3.7/site-packages/sklearn/metrics/classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     248
#     249     """
# --> 250     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     251     if y_type not in ("binary", "multiclass"):
#     252         raise ValueError("%s is not supported" % y_type)
#
# ~/miniconda3/envs/ipp/lib/python3.7/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of binary and multilabel-indicator targets
